# %% [markdown]
# <a href="https://colab.research.google.com/github/RaianaSeixas/Ploblems_Optimization/blob/master/RASTRIGIN_Graph_3d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import *
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

#if using a Jupyter notebook, include: %matplotlib inline
'''#Abrir gráfico em nova janela
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'qt')'''


x = np.arange(-5.12,5.12,0.1)
y = np.arange(-5.12,5.12,0.1)
X,Y = np.meshgrid(x,y)

Z=10 * 2 + np.power(X, 2) - 10 * np.cos(2 * np.pi * X) + np.power(Y, 2) - 10 * np.cos(2 * np.pi * Y)

#fig = plt.figure(figsize=(6,6))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax.grid(False) # esconder linhas de grade
#mycmap = plt.get_cmap('gist_earth')
mycmap = plt.get_cmap('jet')
#ax.set_title('gist_earth color map')
#ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
surf1 = ax.plot_surface(X, Y, Z, cmap=mycmap)
#surf1 = ax1.plot_surface(X, Y, Z, cmap=cm.coolwarm)
fig.colorbar(surf1, ax=ax, shrink=0.5, aspect=5)

cset = ax.contour(X, Y, Z, zdir='z', offset=-10, cmap=mycmap)
plt.show()
